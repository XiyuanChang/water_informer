# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# deeponet_a = pd.read_csv('data_plot/deeponet_A_s.csv').values
# deeponet_b = pd.read_csv('data_plot/deeponet_B_s.csv').values
# deeponet_c = pd.read_csv('data_plot/deeponet_C_s.csv').values

# deeponet_a = pd.read_csv('saved_deepOnetA/models/Mnist_LeNet/0525_144048/predictions/metric/metric.csv').values
# deeponet_b = pd.read_csv('saved_deepOnetB/models/Mnist_LeNet/0525_152914/predictions/metric/metric.csv').values
# deeponet_c = pd.read_csv('saved_deepOnetC/models/Mnist_LeNet/0525_153539/predictions/metric/metric.csv').values

# deeponet_a = pd.read_csv('saved_deepOnetA/models/Mnist_LeNet/0525_024412/predictions/metric/metric.csv').values
# deeponet_b = pd.read_csv('saved_deepOnetB/models/Mnist_LeNet/0525_024525/predictions/metric/metric.csv').values
deeponet_c = pd.read_csv('saved_deepOnetC_31/models/Mnist_LeNet/1005_160700/predictions/metric/metric.csv').values

# lstm_a = pd.read_csv('data_plot/LSTM_A.csv').values
# lstm_b = pd.read_csv('data_plot/LSTM_B.csv').values
lstm_c = pd.read_csv('saved_lstmC/models/lstm/0622_091243/predictions/metric/metric.csv').values

deeponet_kge_index = [1, 5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 45, 49, 53, 57, 61, 65, 69, 73, 77]
deeponet_pbias_index = [2, 6, 10, 14, 18, 22, 26, 30, 34, 38, 42, 46, 50, 54, 58, 62, 66, 70, 74, 78]
deeponet_r2_index = [3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75, 79]

lstm_kge_index = [1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58]
lstm_r2_index = [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59]
lstm_pbias_index = [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60]

# deeponet
# deeponet_a_kge, deeponet_a_r2, deeponet_a_pbias = deeponet_a[:, deeponet_kge_index], deeponet_a[:, deeponet_r2_index], deeponet_a[:, deeponet_pbias_index]
# deeponet_b_kge, deeponet_b_r2, deeponet_b_pbias = deeponet_b[:, deeponet_kge_index], deeponet_b[:, deeponet_r2_index], deeponet_b[:, deeponet_pbias_index]
deeponet_c_kge, deeponet_c_r2, deeponet_c_pbias = deeponet_c[:, deeponet_kge_index], deeponet_c[:, deeponet_r2_index], deeponet_c[:, deeponet_pbias_index]

# lstm 
# lstm_a_kge, lstm_a_r2, lstm_a_pbias = lstm_a[:, lstm_kge_index], lstm_a[:, lstm_r2_index], lstm_a[:, lstm_pbias_index]
# lstm_b_kge, lstm_b_r2, lstm_b_pbias = lstm_b[:, lstm_kge_index], lstm_b[:, lstm_r2_index], lstm_b[:, lstm_pbias_index]
lstm_c_kge, lstm_c_r2, lstm_c_pbias = lstm_c[:, lstm_kge_index], lstm_c[:, lstm_r2_index], lstm_c[:, lstm_pbias_index]
# Out:
# (482, 20)

# %%
# KGE
df1 = pd.DataFrame(deeponet_a_kge, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_a_kge, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('A Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('KGE')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/KGE_A.png', bbox_inches='tight')
plt.show()

# R2

df1 = pd.DataFrame(deeponet_a_r2, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_a_r2, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('A Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('R2')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/R2_A.png', bbox_inches='tight')
plt.show()

# PBIAS

df1 = pd.DataFrame(deeponet_a_pbias, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_a_pbias, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('A Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('PBIAS')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/PBIAS_A.png', bbox_inches='tight')
plt.show()

# %%
# KGE
df1 = pd.DataFrame(deeponet_b_kge, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_b_kge, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('B Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('KGE')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/KGE_B.png', bbox_inches='tight')
plt.show()

# R2

df1 = pd.DataFrame(deeponet_b_r2, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_b_r2, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('B Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('R2')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/R2_B.png', bbox_inches='tight')
plt.show()

# PBIAS

df1 = pd.DataFrame(deeponet_b_pbias, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_b_pbias, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('B Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('PBIAS')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/PBIAS_B.png', bbox_inches='tight')
plt.show()

# %%
# KGE
df1 = pd.DataFrame(deeponet_c_kge, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_c_kge, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('C Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('KGE')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/KGE_C.png', bbox_inches='tight')
plt.show()

# R2

df1 = pd.DataFrame(deeponet_c_r2, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_c_r2, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('C Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('R2')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/R2_C.png', bbox_inches='tight')
plt.show()

# PBIAS

df1 = pd.DataFrame(deeponet_c_pbias, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df1['Dataset'] = 'DeepOnet'
df2 = pd.DataFrame(lstm_c_pbias, columns=['Temp', 'Cond', 'DO', 'pH', 'CO2', 'TN', 'N-org', 'NO3', 'PO4', 'TP', 'NPOC', 'Ca', 'Mg', 'Na', 'K', 'Cl', 'SO4', 'SiO2', 'NHx', 'SSC'])
df2['Dataset'] = 'LSTM'

# 合并两个DataFrame
df_combined = pd.concat([df1, df2])

# 将数据转为长格式
df_melted = pd.melt(df_combined, id_vars=['Dataset'], var_name='Group', value_name='Value')

# 绘制箱线图
plt.figure(figsize=(15, 10))
ax = sns.boxplot(x='Group', y='Value', hue='Dataset', data=df_melted, showfliers=False)
ax.set_title('C Setting')
ax.set_xlabel('Groups')
ax.set_ylabel('PBIAS')
plt.xticks(rotation=45)
plt.legend(title='Method')
plt.savefig('figures/PBIAS_C.png', bbox_inches='tight')
plt.show()
